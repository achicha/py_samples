# %%
from grab import Grab
'''grab symbol urls from LSE and write them to the file'''


g = Grab()
url = 'http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/indices/constituents-indices.html?index=MCX&page='
url_pageLst = []
url_stocksLst = []
count_urls = 0

for i in range(1,14):
    url_num = url + str(i)
    url_pageLst.append(url_num)

for elem in url_pageLst:
    g.go(elem)
    for i in g.doc.select('//*[@id="fullcontainer"]/div/table/tbody/tr/td[2]/a'):
        count_urls+=1
        url_stocksLst.append('http://www.londonstockexchange.com' + i.attr('href'))

print(count_urls)
#print(url_stocksLst)
# Out:
# 250

# %%
url_stocksLst
# Out:
# ['http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/summary/company-summary/JE00BYR8GK67JEGBXSTMM.html',
#  'http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/summary/company-summary/GB00BMSKPJ95GBGBXSTMM.html',
#  'http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/summary/company-summary/GB0000031285GBGBXSTMM.html',
#  'http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/summary/company-summary/GB0000066554GBGBXSTMM.html',
#  'http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/summary/company-summary/GB00B61D2N63GBGBXSTMM.html',
#  'http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/summary/company-summary/GB00BK1PTB77GBGBXSTMM.html',
#  'http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/summary/company-summary/GB00BQQMCJ47GBGBXSTMM.html',
# ...

# %%
import time
"""
write to the file IHE/Description/Link
"""
with open('symbols_FTSE250.txt', 'wt') as f:
    ihe_dict={}
    for y in url_stocksLst:
        time.sleep(3)
        g.go(y)
        try:
            for w in g.doc.select('//*[@id="box-testata"]/div/h1'):
                print(((y.split(".")[-2].split('/')[-1])+' '+w.text()))
                ihe_dict[(str(y.split(".")[-2].split('/')[-1]))[:-9]]=(w.text() +' '+y)
                #print(ihe_dict)
                f.write((y.split(".")[-2].split('/')[-1])+' '+w.text())
                f.write('\n')
        except:
            pass

print('FINISH')
# Out:
# JE00BYR8GK67JEGBXSTMM 3IN 3I INFRASTRUCTURE PLC ORD NPV
# GB00BMSKPJ95GBGBXSTMM AA. AA PLC ORD 0.1P
# GB0000031285GBGBXSTMM ADN ABERDEEN ASSET MANAGEMENT PLC ORD 10P
# GB0000066554GBGBXSTMM ASL ABERFORTH SMALLER COMPANIES TRUST PLC ORD 1P
# GB00B61D2N63GBGBXSTMM ACA ACACIA MINING PLC ORD 10P
# GB00BK1PTB77GBGBXSTMM AGK AGGREKO PLC ORD 4 329/395P
# GB00BQQMCJ47GBGBXSTMM ALD ALDERMORE GROUP PLC ORD GBP0.10
# GB00B11V7W98GBGBXSTMM ATST ALLIANCE TRUST PLC ORD 2.5P
# GB00BLRLH124GBGBXSTMM ALM ALLIED MINDS PLC ORD 1P
# GB0000282623GBGBXSTMM AMFW AMEC FOSTER WHEELER PLC ORD 50P
# GB00BJTNFH41GBGBXSTMM AO. AO WORLD PLC ORD 0.25P
# GB00BYM8GJ06GBGBXSTMM ASCL ASCENTIAL PLC ORD 1P
# GB00B132NW22GBGBXSTMM ASHM ASHMORE GROUP PLC ORD 0.01P
# GB00BVGBWW93GBGBXSTMM AGR ASSURA PLC ORD 10P
# GB0000608009GBGBXSTMM ATK ATKINS (WS) PLC ORD 0.5P
# GB00BVYVFW23GBGBXSTMM AUTO AUTO TRADER GROUP PLC ORD 1P
# GB00BBG9VN75GBGBXSTMM AVV AVEVA GROUP PLC ORD 3 5/9P
# ...

# %%
"""grab all intraday links with trading data between 8 and 9.15 am"""
intraday_links = []

with open('symbols_FTSE250.txt', 'tr') as f:
    for line in f:
        url = 'http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=0&fourWayKey={IHE}&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15'
        intraday_links.append(url.format(IHE=line.split(' ')[0]))

# %%
for i in ihe_dict.keys():
    print(i)
# Out:
# GB0000767003
# GB00B9NWP991
# GB0002148343
# GB0003452173
# GB00B01D1K48
# GG00B3KX4Q34
# GB0003085445
# GB00B1FW5029
# GB00BRS65X63
# GB0031698896
# GB00B01FLL16
# GB0005622542
# GB00BG49KP99
# GB0001859296
# GB0006886666
# GB00B1QH8P22
# GB0007282386
# GB0007958233
# GB00BYM8GJ06
# GB00B04V1276
# GB00BBG9VN75
# GB00B0HZP136
# GB00BK1PKQ95
# GB00BCRX1J15
# GB00B132NW22
# GB0004052071
# GB00BVG1CF25
# GB00B82YXW83
# GB00B11V7W98
# GB0009292243
# GB00B1L5QH97
# GB0006928617
# GB00B1VNST91
# GB00B1FP6H53
# GB0006215205
# GB00B2987V85
# GB00BMHTHT14
# GB00BYT1DJ19
# GB00B18V8630
# GB0006827546
# LU1072616219
# GB0001001592
# GB0001048619
# GB00B61D2N63
# GB00BYNVD082
# GB0003395000
# GB00B3MBS747
# GB0007590234
# GB0002869419
# IE0003864109
# GB00BLP57Y95
# JE00BN574F90
# GB0003418950
# JE00BD9WR069
# GB00B5ZN1N88
# GB00BMSKPJ95
# GB00B1FP8915
# GB0005203376
# GB00BVFNZH21
# GB00B1CKQ739
# GB0008825324
# GB0003450359
# GB00B188SR50
# GB0004270301
# GB0030232317
# GB00B8KJH563
# ...

# %%
new_symbols = ['GB00B39J2M42GBGBXSET1',
'GB0004544929GBGBXSET1',
'GB00B1XH2C03GBGBXSTMM',
'GB00BDVZYZ77GBGBXSET1',
'GB0009895292GBGBXSET0',
'GB00B1VZ0M25GBGBXSET1',
'GB00BDZT6P94GBGBXSET1',
'GB00BPXRVT80GBGBXSSMM',
'JE00B6T5S470JEGBXSTMM',
'GB00B1WY2338GBGBXSET1',
'JE00B2QKY057JEGBXSET1',
'GB00B8HX8Z88GBGBXSTMM',
'GB00B19NLV48JEGBXSET1',
'GB0009303123GBGBXSTMM',
'GB00B1CRLC47GBGBXSET1',
'GB00B24CGK77GBGBXSET1',
'IE00B1GKF381IEEURSET2',
'GB0031192486GBGBXSTMM',
'GB00B24CT194GBGBXSTMM',
'IE0001827041IEGBXSET1',
'GB0006825383GBGBXSET1',
'GB00B2QPKJ12GBGBXSET1',
'GB00B5SGVL29GBGBXASQ1',
'GB0007669376GBGBXSTMM',
'DE000TUAG000GBGBXSET1',
'GB00B0SWJX34GBGBXSET1',
'GB0007739609GBGBXSET1',
'GB0009457366GBGBXSSMU',
'GB0009376368GBGBXSSMM',
'GB0004228648GBGBXSTMM',
'USU210051004GGGBXASX1',
'GB0000293620GBGBXSSMM',
'GB00B28HSF71GBGBXASQ1',
'GB0008085614GBGBXSSMM',
'GB0001576163GBGBXSSMM',
'IE00B010DT83IEEURSET3',
'GG00B1NPGZ52GGEURSTMM',
'US92343V1044USUSDSSMU',
'GG00B2QQPS89GGUSDSTMM',
'GB0003362992GBGBXSSQ3',
'GB00B8B4R053GBGBXSSMM']

# %%
for i in new_symbols:
    print(i[:-9])
# Out:
# GB00B39J2M42
# GB0004544929
# GB00B1XH2C03
# GB00BDVZYZ77
# GB0009895292
# GB00B1VZ0M25
# GB00BDZT6P94
# GB00BPXRVT80
# JE00B6T5S470
# GB00B1WY2338
# JE00B2QKY057
# GB00B8HX8Z88
# GB00B19NLV48
# GB0009303123
# GB00B1CRLC47
# GB00B24CGK77
# IE00B1GKF381
# GB0031192486
# GB00B24CT194
# IE0001827041
# GB0006825383
# GB00B2QPKJ12
# GB00B5SGVL29
# GB0007669376
# DE000TUAG000
# GB00B0SWJX34
# GB0007739609
# GB0009457366
# GB00B0LCW083
# GB00B1JQBT10
# GB0030927254
# GB00B70FPS60
# GB0031215220
# GB00B01C3S32
# GB00B1FH8J72
# GB0003345054
# GB00B1Z4ST84
# GB00B0744B38
# JE00BFNWV485
# GB0032089863
# GB00B01HM147
# GB0001297562
# GB00B1CL5249
# GB00B6774699
# GB0002335270
# GB00B45C9X44
# GB0001528156
# GB00B1L8B624
# GB00B1KJJ408
# GB00BN33FD40
# GB0007448250
# GB0007995243
# GB00B02J6398
# GB0005746358
# GB0002405495
# GB0005774855
# CH0198251305
# GB00B41H7391
# GB0031638363
# GB0031509804
# GB00B03HDJ73
# GB0004726096
# GB00B572ZV91
# GB0001741544
# VGG379591065
# GI000A0F6407
# ...

# %%
new_links_list = []
from grab import Grab

g = Grab()
for i in new_symbols:
    url = 'http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=0&fourWayKey={IHE}&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15'.format(IHE=i)
    new_links_list.append(url)

# %%
new_links_list
# Out:
# ['http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=0&fourWayKey=GB00B39J2M42GBGBXSET1&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15',
#  'http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=0&fourWayKey=GB0004544929GBGBXSET1&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15',
#  'http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=0&fourWayKey=GB00B1XH2C03GBGBXSTMM&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15',
#  'http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=0&fourWayKey=GB00BDVZYZ77GBGBXSET1&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15',
#  'http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=0&fourWayKey=GB0009895292GBGBXSET0&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15',
# ...

# %%
how_many_intraday_pages = {}

# %%
for i in new_links_list:
    if i not in how_many_intraday_pages.keys():
        g.go(i)
        try:
            for j in g.doc.select('//div[@class="paging"]'):
                print(j.text().split('|')[0].split(' ')[-2])
                how_many_intraday_pages[i] = j.text().split('|')[0].split(' ')[-2]
                break
        except:
            print('except')
# Out:
# 75
# 56
# 266
# 28
# 35
# 38
# 24
# 83
# 42
# 139
# 103
# 1
# 15
# 31
# 48
# 19
# 5
# 64
# 33
# 62
# 60
# 8
# 41
# 56
# 90
# 1
# 3
# 1
# 14
# 78
# 5
# 19
# 5
# 41
# 25
# 4
# 21
# 2
# 3
# 1
# 1
# 1
# 2
# 1
# 1
# 2
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 2
# 1
# 4
# 1
# 1
# 1
# 1
# 2
# 1
# 1
# 1
# 1
# 1

# %%
len(how_many_intraday_pages)
# Out:
# 66

# %%
"""find all intraday links for download"""
con = 0
total_links = []
for k in how_many_intraday_pages.keys():
    pages = how_many_intraday_pages[k]
    [print(pages)]
    for page in range(0, (int(pages))):
        con +=1
        link = k.replace('page=0', 'page={}'.format(page))
        print(link)
        total_links.append(link)
        
print(con)
# Out:
# 1
# http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=0&fourWayKey=GB00B18JK166GBGBXSSMM&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15
# 103
# http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=0&fourWayKey=GB00B2QPKJ12GBGBXSET1&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15
# http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=1&fourWayKey=GB00B2QPKJ12GBGBXSET1&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15
# http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=2&fourWayKey=GB00B2QPKJ12GBGBXSET1&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15
# http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=3&fourWayKey=GB00B2QPKJ12GBGBXSET1&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15
# ...

# %%
how_many_intraday_pages
# Out:
# {'http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=0&fourWayKey=CH0198251305GBGBXSET1&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15': '25',
#  'http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=0&fourWayKey=DE000TUAG000GBGBXSET1&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15': '15',
#  'http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=0&fourWayKey=GB0000163088GBGBXSSMM&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15': '1',
#  'http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=0&fourWayKey=GB0000293620GBGBXSSMM&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15': '1',
# ...

# %%
'''save all links'''
with open('total_LSE_2.txt', 'tw') as f:
    for i in total_links:
        f.write(i)
        f.write('\n')

# %%
"""grab intraday data"""
completed = []

# %%
# url = 'http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=0&fourWayKey=GB00BMHTHT14GBGBXSTMM&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15'


with open('resuls_2.txt', 'at') as f:
    while len(total_links) != len(completed):
        try:
            for url in total_links:
                if url not in completed:
                    g.go(url)
                    print(url)
                    trr = []
                    for d in g.doc.select('//div[@class="table-responsive"]'):
                        for tr in d.select('//tbody/tr'):
                            if 'Oct' in tr.text() or 'ISIN' in tr.text():
                                #print(tr.text())
                                if tr.text() not in trr:
                                    trr.append(tr.text())   
                        break 
                    print(trr)
                    for i in trr:
                        f.write(i)
                        f.write('\n')
                    trr.clear()
                    completed.append(url)

                else:
                    print('already exist')
        except:
            continue
# Out:
# http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=0&fourWayKey=GB00B18JK166GBGBXSSMM&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15
# ['09:14:06 17-Oct-2016 253.50 1,979 5,016.76 Ordinary trade', 'ISIN number GB00B18JK166']
# http://www.londonstockexchange.com/exchange/prices-and-markets/stocks/exchange-insight/trade-data.html?page=0&fourWayKey=GB00B2QPKJ12GBGBXSET1&formName=frmDateTime&hh1=8&mm1=-1&hh2=9&mm2=15
# ...

# %%
# todo
"""асинхронный парсер"""

# %% [markdown]
# -------------

# %%
"""
create list with CQG symbols
"""

cqg='''GB00B61D2N63
GB00BK1PTB77
GB00BVGBWW93
GB00BQQMCJ47
GB00BLRLH124
GB0000282623
'''
cqg_lst=cqg.split('\n')

# %%
"""
create final file with diff names between ALL-CQG
"""
diff_lst={}
nums=0
for k,v in ihe_dict.items():
    if k in cqg_lst:
        continue
    else:
        nums+=1
        diff_lst[k]=v
print(diff_lst)
print(nums)
with open('diffFTSE.txt', 'wt') as f:
    for k,v in diff_lst.items():
        f.write(k)
        f.write('  ')
        f.write(v)
        f.write('\n')

# %%
l = """GKP 17247607
LLOY 30325
BARC 29206
VOD 31177
GLEN 975509
TSCO 30908
HSBA 30316
BP 29739
IAG 946880
ITV 114113
RBOS 30406
#  '30383',
#  '30006',
#  '29698',
#  '30335',
#  '18718626',
#  '28317',
#  '29100',
#  '30626',
#  '34913',
#  '34902',
#  '750627',
#  '30830',
#  '30327',
#  '30400',
#  '30421',
#  '85517',
#  '272143',
#  '29773',
#  '85825',
#  '34856',
#  '31055',
#  '30420',
#  '34802',
#  '30300',
#  '315930',
#  '30401',
#  '28640',
#  '17336694',
#  '35076',
#  '30687',
#  '30104',
#  '35006',
#  '30419',
#  '34818',
#  '228866',
#  '34797',
#  '30310',
#  '29344',
#  '31197',
#  '30318',
#  '34824',
#  '268290',
#  '30323',
#  '30259',
#  '35044',
#  '121797',
#  '121823',
#  '29164',
#  '33317',
#  '30669',
#  '30803',
#  '17165112',
#  '315931',
#  '31157',
#  '30319',
#  '726498',
#  '16662349',
#  '29354',
#  '747840',
#  '18902770',
#  '98922',
#  '1029059',
#  '30040',
# ...

# %%
from grab import Grab

g = Grab()



_headers = {'Accept-Language': 'ru-RU,ru;q=0.8,en-US;q=0.6,en;q=0.4',
           'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.143 Safari/537.36',
           'Content-Type': 'application/json; charset=UTF-8',
           'Accept': 'application/json, text/javascript, */*; q=0.01',
           'Referer': 'http://charts.londonstockexchange.com/chart/CompanySummaryChart2_image.aspx?mcode=TIT.3IN.LD&key=JE00BYR8GK67JEGBXSTMM&imageFormat=png',
           'X-Requested-With': 'XMLHttpRequest',
           'Connection': 'keep-alive'}

_post = """{"request":{"SampleTime":"1mm","TimeFrame":"1d","RequestedDataSetType":"ohlc","ChartPriceType":"price","Key":"3IN.LD","OffSet":-60,"FromDate":null,"ToDate":null,"UseDelay":true,"KeyType":"Topic","KeyType2":"Topic","Language":"en"}}"""

_url = 'http://charts.londonstockexchange.com/WebCharts/services/ChartWService.asmx/GetPrices'

g.go(url=_url, headers=_headers, post=_post)

# %%
print(g.doc.body)
# Out:
# b'{"d":[[1476777600000,191.3,191.3,191.3,191.3,191.3],[1476777660000,192.5,192.5,192.5,192.5,192.5],[1476778020000,192.5,192.5,192.5,192.5,192.5],[1476778200000,192.3,192.3,192.3,192.3,192.3],[1476779940000,192.2,192.2,192.2,192.2,192.2],[1476780420000,192.293,192.293,192.293,192.293,192.293],[1476780900000,192.392,192.392,192.392,192.392,192.392],[1476781800000,192.392,192.392,192.392,192.392,192.392],[1476782640000,191.6,191.6,191.6,191.6,191.6],[1476783180000,191.5,191.5,191.5,191.5,191.5],[1476783300000,191.5,191.5,191.5,191.5,191.5],[1476783360000,191.796,191.796,191.796,191.796,191.796],[1476783660000,191.796,191.796,191.796,191.796,191.796],[1476783720000,191.796,191.796,191.796,191.796,191.796],[1476783840000,191.796,191.796,191.796,191.796,191.796],[1476783900000,191.796,191.796,191.796,191.796,191.796],[1476784080000,191.796,191.796,191.796,191.796,191.796],[1476784500000,191.8,191.8,191.8,191.8,191.8],[1476784800000,191.796,191.796,191.796,191.796,191.796],[1476785040000,1
# ...
